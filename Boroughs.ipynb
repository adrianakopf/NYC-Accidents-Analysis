# %%
import pandas as pd

# %%
data = pd.read_csv("NYPD data.csv")

data.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2714: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         DATE  TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  4/22/2019  0:05  MANHATTAN    10002  40.716476  -73.99283
# 1  4/22/2019  0:15   BROOKLYN    11238  40.681750  -73.96748
# 2  4/22/2019  0:15     QUEENS    11434  40.664017  -73.76860
# 3  4/22/2019  0:30   BROOKLYN    11219  40.622326  -73.99806
# 4  4/22/2019  0:30   BROOKLYN    11228  40.607464  -74.01486
#
#                  LOCATION                    ON STREET NAME  \
# 0  (40.716476, -73.99283)  ELDRIDGE STREET
# 1   (40.68175, -73.96748)  ATLANTIC AVENUE
# 2   (40.664017, -73.7686)  FARMERS BOULEVARD
# 3  (40.622326, -73.99806)                               NaN
# 4  (40.607464, -74.01486)                               NaN
#
# ...

# %%
manhattan = data.loc[data["BOROUGH"] == "MANHATTAN"]
queens = data.loc[data["BOROUGH"] == "QUEENS"]
bronx = data.loc[data["BOROUGH"] == "BRONX"]
brooklyn = data.loc[data["BOROUGH"] == "BROOKLYN"]
statenisland = data.loc[data["BOROUGH"] == "STATEN ISLAND"]
# Out:
#           DATE   TIME        BOROUGH ZIP CODE  LATITUDE  LONGITUDE  \
# 31   4/22/2019  11:35  STATEN ISLAND    10302  40.62961  -74.13026
# 38   4/22/2019  12:00  STATEN ISLAND    10305  40.61194  -74.07038
# 45   4/22/2019  12:20  STATEN ISLAND    10304  40.60323  -74.09261
# 205  4/22/2019  19:15  STATEN ISLAND    10305  40.57925  -74.07781
# 219  4/22/2019  20:35  STATEN ISLAND    10306  40.57912  -74.13289
#
#                   LOCATION                    ON STREET NAME  \
# 31   (40.62961, -74.13026)  JEWETT AVENUE
# 38   (40.61194, -74.07038)                               NaN
# 45   (40.60323, -74.09261)  RICHMOND ROAD
# 205  (40.57925, -74.07781)  CAPODANNO BOULEVARD
# 219  (40.57912, -74.13289)                               NaN
#
#     CROSS STREET NAME                           OFF STREET NAME  \
# 31     HOLBERNT COURT                                       NaN
# 38                NaN  255       HYLAN BOULEVARD
# ...

# %%
m_count = manhattan["CONTRIBUTING FACTOR VEHICLE 1"].value_counts().nlargest(5)
q_count = queens["CONTRIBUTING FACTOR VEHICLE 1"].value_counts().nlargest(5)
bronx_count = bronx["CONTRIBUTING FACTOR VEHICLE 1"].value_counts().nlargest(5)
brooklyn_count = brooklyn["CONTRIBUTING FACTOR VEHICLE 1"].value_counts().nlargest(5)
s_count = statenisland["CONTRIBUTING FACTOR VEHICLE 1"].value_counts().nlargest(5)
s_count
# Out:
# Unspecified                       19882
# Driver Inattention/Distraction     8047
# Failure to Yield Right-of-Way      2597
# Backing Unsafely                   1978
# Following Too Closely              1593
# Name: CONTRIBUTING FACTOR VEHICLE 1, dtype: int64
